# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('Income_Stats.xlsx')

# %%
df.head(20)
# Out:
#     Name   Income
# 0    Rob     5000
# 1  Rafiq     6000
# 2   Nina     4000
# 3  Sofia     7500
# 4  Mohan     8000
# 5    Tou     4000
# 6   Musk  1000000

# %%
df.describe()
# Out:
#                Income
# count        7.000000
# mean    147785.714286
# std     375794.475871
# min       4000.000000
# 25%       4500.000000
# 50%       6000.000000
# 75%       7750.000000
# max    1000000.000000

# %%
# Removing Outliers

df.Income.quantile(0.75)
# Out:
# 7750.0

# %%
df.Income.quantile(0.25)
# Out:
# 4500.0

# %%
df.Income.quantile(0.25, interpolation='lower')
# Out:
# 4000

# %%
df.Income.quantile(0.25, interpolation='higher')
# Out:
# 5000

# %%
percentile_99=df.Income.quantile(0.99)
percentile_99
# Out:
# 940479.9999999995

# %%
df[df.Income>percentile_99]
# Out:
#    Name   Income
# 6  Musk  1000000

# %%
df_no_outlier=df[df.Income<=percentile_99]
df_no_outlier
# Out:
#     Name  Income
# 0    Rob    5000
# 1  Rafiq    6000
# 2   Nina    4000
# 3  Sofia    7500
# 4  Mohan    8000
# 5    Tou    4000

# %%
# Filling a Missing value

df['Income'][3]=np.NaN
# Out:
# C:\Users\PushkarJaiswal\AppData\Local\Temp\ipykernel_13192\2449499821.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Income'][3]=np.NaN

# %%
df
# Out:
#     Name     Income
# 0    Rob     5000.0
# 1  Rafiq     6000.0
# 2   Nina     4000.0
# 3  Sofia        NaN
# 4  Mohan     8000.0
# 5    Tou     4000.0
# 6   Musk  1000000.0

# %%
df.Income.mean()
# Out:
# 171166.66666666666

# %%
df_new=df.fillna(df.Income.mean())
df_new
# Out:
#     Name          Income
# 0    Rob     5000.000000
# 1  Rafiq     6000.000000
# 2   Nina     4000.000000
# 3  Sofia   171166.666667
# 4  Mohan     8000.000000
# 5    Tou     4000.000000
# 6   Musk  1000000.000000

# %%
df_new1=df.fillna(df.Income.median())
df_new1
# Out:
#     Name     Income
# 0    Rob     5000.0
# 1  Rafiq     6000.0
# 2   Nina     4000.0
# 3  Sofia     5500.0
# 4  Mohan     8000.0
# 5    Tou     4000.0
# 6   Musk  1000000.0

# %%
df1=pd.read_csv('AB_NYC_2019.csv')
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
min_thresold,max_thresold=df1.price.quantile([0.01,0.999])
min_thresold,ma_thresold
# Out:
# (30.0, 3000.0)

# %%
df1[df1.price<min_thresold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df1[df1.price<min_thresold]
# Out:
#              id                                             name    host_id  \
# 957      375249                  Enjoy Staten Island Hospitality    1887999
# 2675    1428154              Central, Peaceful Semi-Private Room    5912572
# 2860    1620248    Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3020    1767037               Small Cozy Room Wifi & AC near JFK    9284163
# 3918    2431607                    Bright, Airy Room Share for 2    4973668
# ...         ...                                              ...        ...
# 48486  36280646                     Cable and wfi, L/G included.  272872092
# 48647  36354776    Cozy bedroom in diverse neighborhood near JFK  273393150
# 48832  36450814                         FLATBUSH HANG OUT AND GO  267223765
# 48867  36473044  The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                     Heaven for you(only for guy)  261338177
#
# ...

# %%
df2=df1[(df1.price>min_thresold)&(df1.price<max_thresold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.sample(5)
# Out:
#              id                                               name    host_id  \
# 1551     702213                 W'burg Hidden Treasure Off Lorimer     240471
# 8775    6731830                  Williamsburg Apartment on Bedford   30345458
# 10775   8290210              Overlooking NYC skyline in Greenpoint   41152325
# 24660  19812097  Two B/Rm (2-3 guests) Near Beach, A/air train,...  139957134
# 26786  21263008  4 Beds 4 Baths serviced apartment Palazzo Gram...  153735730
#
#       host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 1551    Roberto            Brooklyn  Williamsburg  40.70751  -73.94670
# 8775     Thomas            Brooklyn  Williamsburg  40.71444  -73.96024
# 10775      I-Nu            Brooklyn    Greenpoint  40.72373  -73.94537
# 24660     Trudy              Queens       Arverne  40.59910  -73.79944
# 26786     Sudha           Manhattan      Gramercy  40.73680  -73.98307
#
# ...

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64
